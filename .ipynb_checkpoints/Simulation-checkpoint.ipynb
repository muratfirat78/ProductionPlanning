# %% [markdown]
# <img align="right" width="125" src="https://www.ou.nl/documents/40554/3255217/Logo_OU.jpg"/>
#
# <br>
#
#
# <center> <font size ="6" color='red'> AI for Prescriptive Analysis </font></center>
# <br>
# <center> <font size ="5" color='red'> Discrete Event Simulation in Python</font></center>
# <br>

# %% [markdown]
# --------------------------

# %%
from Controller import*
mycontroller = Controller()
mytab = mycontroller.GetDashBoard(); milptab = mycontroller.GenerateMILPTab()
tab_set = widgets.Tab([mytab,milptab])
tab_set.set_title(0,'Main');tab_set.set_title(1,'MILP'); tab_set
# Out:
# Start day:  2026-08-13  weekday:  3  day:  Thursday , TimeLimit:  None
# Controller: Generating dashboard
# Visual Manager: Generating dashboard
# Tab(children=(VBox(children=(Label(value='TimeLimit: 57600, Orders: 249'), HBox(children=(Select(description='…

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

exec_df = pd.read_csv("EventExecutionData.csv")


for batch in exec_df["Items"].unique():
    if pd.isnull(batch):
        continue
    sub_df = exec_df[exec_df["Items"] == batch]
    sub_df = sub_df.sort_values(['SimTime'])
    start = sub_df.iloc[0, sub_df.columns.get_loc('Location')]
    end = sub_df.iloc[len(sub_df)-1, sub_df.columns.get_loc('Location')]

    if start != end:
        display(sub_df)
    
        print("______________________________")

print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
exec_df = pd.read_csv("BufferData.csv")

for buff in exec_df["BufferName"].unique():
    sub_df = exec_df[exec_df["BufferName"] == buff]
    agg_df = sub_df.groupby(['BufferName','Time'])['No.Items'].max().reset_index()
    agg_df = agg_df.rename(columns={agg_df.columns[-1]: "No.Items"})

    if buff in ["Central_Output","Central_Input"]:
        sns.barplot(agg_df, x="Time", y="No.Items", legend=False).set_title(buff)
        plt.xticks(rotation=45)
        plt.show()
        
        display(agg_df.head(100))
        print("______________________________")
# Out:
#               EventName  EventID            ProgressSteps  \
# 136     Trailer Loading       35                  522-523
# 139   Trailer Transport      171                  523-524
# 142   Trailer Unloading      175                  524-525
# 627       Machine Setup      178              11159-11160
# 662     Machine Loading      859              12046-12047
# 690   Machine Unloading      917              12296-12297
# 691  Machine Processing      916  12046-12061~12296-12297
# 703     Trailer Loading      944              12474-12475
# 704   Trailer Transport      957              12475-12476
# 705   Trailer Unloading      958              12476-12477
# 721       Machine Setup      959              12557-12617
# 748     Machine Loading      992              16330-16334
# 793   Machine Unloading     1049              16433-16434
# 794  Machine Processing     1048  16330-16425~16433-16434
# 800     Trailer Loading     1091              16437-16438
# 801   Trailer Transport     1097              16438-16439
# 802   Trailer Unloading     1098              16439-16440
# 838       Machine Setup     1099              16864-16865
# 844     Machine Loading     1145              17207-17208
# 845  Machine Processing     1151              17207-17208
#
#                                                  Items  \
# 136  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 139  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 142  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 627  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 662  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 690  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 691  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 703  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 704  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 705  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 721  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 748  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 793  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 794  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 800  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 801  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 802  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 838  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 844  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
# 845  7281~7282~7283~7284~7285~7286~7287~7288~7289~7...
#
#                                               Resource  \
# 136                                         Operator 1
# 139                                         Operator 1
# 142                                         Operator 1
# 627                                         Operator 3
# 662                                         Operator 2
# 690                                         Operator 1
# 691  MP1 - Material preparation - automatic sawing ...
# 703                                         Operator 1
# 704                                         Operator 1
# 705                                         Operator 1
# 721                                         Operator 3
# 748                                    Manual worker 2
# 793                                    Manual worker 2
# 794                                     M4-01_(FR4_01)
# 800                                    Manual worker 2
# 801                                    Manual worker 2
# 802                                    Manual worker 2
# 838                                         Operator 3
# 844                                         Operator 3
# 845                                        BW_(BKW_01)
#
#                                              Equipment  \
# 136                                         Trailer_60
# 139                                         Trailer_60
# 142                                         Trailer_60
# 627  MP1 - Material preparation - automatic sawing ...
# 662  MP1 - Material preparation - automatic sawing ...
# 690  MP1 - Material preparation - automatic sawing ...
# 691  MP1 - Material preparation - automatic sawing ...
# 703                                         Trailer_60
# 704                                         Trailer_60
# 705                                         Trailer_60
# 721                                     M4-01_(FR4_01)
# 748                                     M4-01_(FR4_01)
# 793                                     M4-01_(FR4_01)
# 794                                     M4-01_(FR4_01)
# 800                                         Trailer_60
# 801                                         Trailer_60
# 802                                         Trailer_60
# 838                                        BW_(BKW_01)
# 844                                        BW_(BKW_01)
# 845                                        BW_(BKW_01)
#
#                                               Location  SimTime  \
# 136                             CentralBuffer_Location      523
# 139                                         Trailer_60      524
# 142  MP1 - Material preparation - automatic sawing ...      525
# 627  MP1 - Material preparation - automatic sawing ...    11160
# 662  MP1 - Material preparation - automatic sawing ...    12047
# 690  MP1 - Material preparation - automatic sawing ...    12297
# 691  MP1 - Material preparation - automatic sawing ...    12297
# 703  MP1 - Material preparation - automatic sawing ...    12475
# 704                                         Trailer_60    12476
# 705                            M4-01_(FR4_01)_Location    12477
# 721                            M4-01_(FR4_01)_Location    12617
# 748                            M4-01_(FR4_01)_Location    16334
# 793                            M4-01_(FR4_01)_Location    16434
# 794                            M4-01_(FR4_01)_Location    16434
# 800                            M4-01_(FR4_01)_Location    16438
# 801                                         Trailer_60    16439
# 802                               BW_(BKW_01)_Location    16440
# 838                               BW_(BKW_01)_Location    16865
# 844                               BW_(BKW_01)_Location    17208
# 845                               BW_(BKW_01)_Location    17208
#
#                     Date
# 136  2026-08-13 08:43:00
# 139  2026-08-13 08:44:00
# 142  2026-08-13 08:45:00
# 627  2026-08-20 18:00:00
# 662  2026-08-21 08:47:00
# 690  2026-08-21 12:57:00
# 691  2026-08-21 12:57:00
# 703  2026-08-21 15:55:00
# 704  2026-08-21 15:56:00
# 705  2026-08-21 15:57:00
# 721  2026-08-21 18:17:00
# 748  2026-08-24 08:14:00
# 793  2026-08-24 09:54:00
# 794  2026-08-24 09:54:00
# 800  2026-08-24 09:58:00
# 801  2026-08-24 09:59:00
# 802  2026-08-24 10:00:00
# 838  2026-08-24 17:05:00
# 844  2026-08-24 22:48:00
# 845  2026-08-24 22:48:00
# ______________________________
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#         BufferName  Time  No.Items
# 0   Central_Output     0      7700
# 1   Central_Output   481      7675
# 2   Central_Output   486      7436
# 3   Central_Output   487      7278
# 4   Central_Output   492      6576
# 5   Central_Output   497      4623
# 6   Central_Output   498      3608
# 7   Central_Output   501      2788
# 8   Central_Output   502      2787
# 9   Central_Output   503      2187
# 10  Central_Output   506      2088
# 11  Central_Output   507      1848
# 12  Central_Output   508      1571
# 13  Central_Output   511      1546
# 14  Central_Output   512      1526
# 15  Central_Output   513      1506
# 16  Central_Output   516      1012
# 17  Central_Output   517       992
# 18  Central_Output   518       872
# 19  Central_Output   521       450
# 20  Central_Output   522       420
# 21  Central_Output   523         0
# ______________________________
#        BufferName   Time  No.Items
# 0   Central_Input    499        15
# 1   Central_Input    938        40
# 2   Central_Input   6724        50
# 3   Central_Input   8347        80
# 4   Central_Input  11123        97
# 5   Central_Input  12053        98
# 6   Central_Input  16342       122
# 7   Central_Input  16356      1101
# 8   Central_Input  16414      1521
# 9   Central_Input  16463      1541
# 10  Central_Input  16625      1542
# 11  Central_Input  19217      2066
# 12  Central_Input  19218      3066
# 13  Central_Input  19222      3096
# 14  Central_Input  19298      3182
# 15  Central_Input  19348      3459
# 16  Central_Input  19431      3539
# 17  Central_Input  19484      3589
# 18  Central_Input  19580      3681
# 19  Central_Input  21117      4023
# 20  Central_Input  22326      4263
# 21  Central_Input  26411      4879
# 22  Central_Input  26490      4959
# 23  Central_Input  26618      5079
# 24  Central_Input  27992      5213
# 25  Central_Input  27999      5333
# 26  Central_Input  29335      5357
# 27  Central_Input  30729      6057
# 28  Central_Input  31202      6527
# 29  Central_Input  32169      6551
# 30  Central_Input  36585      6640
# 31  Central_Input  37928      7240
# 32  Central_Input  37929      7260
# 33  Central_Input  41666      7280
# ______________________________

# %%
import pandas as pd

location_df = pd.read_csv("LocationData.csv")

for entity in location_df["EntityID"].unique():
    sub_df = location_df[location_df["EntityID"] == entity]
    display(sub_df)
    print("______________________________")
